# %% [markdown]
# ### Step 1: Data

# %% [markdown]
# #### yahoo download

# %%
import pandas as pd
import numpy as np
import datetime
import itertools
import yfinance as yf

from yahoodownloader import YahooDownloader
from preprocessors import FeatureEngineer, data_split, INDICATORS
import config_tickers

# %%
aapl_df_yf = yf.download(tickers = "aapl", start='2020-01-01', end='2020-01-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_df_yf.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.449371  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.735306  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.314888  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.970070  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  74.143906  132079200

# %%
aapl_df_finrl = YahooDownloader(start_date = '2020-01-01',
                                end_date = '2020-01-31',
                                ticker_list = ['aapl']).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (20, 8)

# %%
aapl_df_finrl.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2020-01-02  74.059998  75.150002  73.797501  73.449402  135480400  aapl
# 1  2020-01-03  74.287498  75.144997  74.125000  72.735306  146322800  aapl
# 2  2020-01-06  73.447502  74.989998  73.187500  73.314880  118387200  aapl
# 3  2020-01-07  74.959999  75.224998  74.370003  72.970085  108872000  aapl
# 4  2020-01-08  74.290001  76.110001  74.290001  74.143898  132079200  aapl
#
#    day
# 0    3
# 1    4
# 2    0
# 3    1
# 4    2

# %%
config_tickers.DOW_30_TICKER
# Out:
# ['AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CSCO',
#  'CVX',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'KO',
#  'JPM',
#  'MCD',
#  'MMM',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'CRM',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT',
#  'DIS',
#  'DOW']

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-29'

# %%
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (94301, 8)

# %%
df_raw.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.758535  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  43.832630    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.308593   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941105    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  31.579340    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3228, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.head()
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2009-01-02  AAPL   3.067143   3.251429   3.041429   2.758535  746015200.0
# 1  2009-01-02  AMGN  58.590000  59.080002  57.750000  43.832630    6547900.0
# 2  2009-01-02   AXP  18.570000  19.520000  18.400000  15.308593   10955700.0
# 3  2009-01-02    BA  42.799999  45.560001  42.779999  33.941105    7010200.0
# 4  2009-01-02   CAT  44.910000  46.980000  44.709999  31.579340    7117200.0
#
#    day  macd  boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0      2.758535
# 1  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     43.832630
# 2  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     15.308593
# 3  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     33.941105
# 4  4.0   0.0  2.98139  2.652101   100.0  66.666667  100.0     31.579340
#
#    close_60_sma        vix  turbulence
# 0      2.758535  39.189999         0.0
# 1     43.832630  39.189999         0.0
# 2     15.308593  39.189999         0.0
# 3     33.941105  39.189999         0.0
# 4     31.579340  39.189999         0.0

# %%
# Split the data for training and trading
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 83897
# 9715

# %%
train.to_csv('train_data.csv', index=False)
trade.to_csv('trade_data.csv', index=False)

# %% [markdown]
# ### Step 2: Single Model
